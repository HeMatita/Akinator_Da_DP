# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt 
import random
from random import randint

# %%
xl = pd.ExcelFile("EP3_dados.xlsx")
xl.sheet_names
['Planilha1']
df = xl.parse()
df
# Out:
#                   Sala   Engenharia Time que torce  Idade Usa óculos  \
# Ariel                C   Computação      São Paulo     18        Não
# Arthur               A   Computação      Palmeiras     18        Sim
# Christiano           C     Mecânica      São Paulo     19        Sim
# Ester                A     Mecânica      São Paulo     18        Não
# Felipe               B     Mecânica      São Paulo     19        Não
# Fernando             B     Mecânica      Palmeiras     20        Não
# Gabriel              C     Mecânica      Palmeiras     17        Não
# Biro                 B   Computação      São Paulo     21        Não
# João Laet            C     Mecânica      São Paulo     18        Não
# Matita               B  Mecatrônica    Corinthians     18        Não
# Matheus              B     Mecânica         Santos     23        Sim
# Pedro dos Santos     A  Mecatrônica         Nenhum     20        Sim
# Pedro Henrique       C  Mecatrônica      Palmeiras     18        Não
# ...

# %%
perguntas = {1 : "Essa pessoa é da sala {}?".format(dic_salas[randint(1,3)]), 2 : "Essa pessoa é de Engenharia {}?".format(dic_engenharias[randint(1,3)]), 3 : "Essa pessoa torce para {}?".format(dic_times[randint(1,6)]), 4 : "Essa pessoa têm {} anos?".format(dic_idade[randint(1,7)]), 5 : "Ela usa óculos?", 6 : "Ela nasceu na cidade de SP?", 7 : "Ela faz academia?", 8 : "Ela dirige?", 9 : "Qual tipo de celular ela prefere?", 10 : "Ela namora?", 11 : "Ela já viajou para fora do Brasil?", 12 : "Essa pessoa têm os olhos de cor {}?".format(dic_olhos[randint(1,3)]), 13 : "O cabelo dessa pessoa é {}?".format(dic_cabelo[randint(1,3)]), 14 : "O tipo de música favorita dessa pessoa é {}?".format(dic_musica[randint(1,10)]), 15 : "Onde ela gostaria de morar?", 16 : "Ela têm irmãos ou irmãs?", 17 : "Ela prefere salgado ou doce?", 18 : "A cor favorita dessa pessoa é {}?".format(dic_cor[randint(1,6)]), 19 : "Ela prefere carro ou avião?", 20 : "Ela prefere frio ou calor?", 21 : "Ela gosta de esportes?", 22 : "Ela foi para o Econo 2017?", 23 : "Ela já trabalhou?", 24 : "Ela prefere chá ou café?", 25 : "Ela prefere filmes ou séries?", 26 : "Ela já viu neve?"}
dic_salas = {1 : "A", 2 : "B", 3 : "C"}
dic_engenharias = {1 : "Mecânica", 2 : "Mecatrônica", 3 : "de Computação"}
dic_times = {1 : "o Santos", 2 : "o Corinthians", 3 : "o Palmeiras", 4 : "o São Paulo", 5 : "o Flamengo", 6 : "nenhum time"}
dic_idade = {1 : "17", 2 : "18", 3 : "19", 4 : "20", 5 : "21", 6 : "23", 7 : "43"}
dic_olhos = {1 : "verde", 2 : "azul", 3 : "castanho"}
dic_cabelo = {1 : "castanho", 2 : "preto", 3 : "loiro"}
dic_musica = {1 : "Pop", 2 : "Rock", 3 : "Rap", 4 : "Gospel", 5 : "Metal", 6 : "Sertanejo", 7 : "Funk", 8 : "Eletro", 9 : "Samba", 10 : "Tecno"}
dic_cor = {1 : "roxo", 2 : "azul", 3 : "verde", 4 : "vermelho", 5 : "cinza", 6 : "preto"}

# %%
p = random.sample(range(1,27), 26)
for i in range(len(p)):
    print(perguntas[p[i]])
# Out:
# Onde ela gostaria de morar?
# Ela namora?
# Qual tipo de celular ela prefere?
# Ela gosta de esportes?
# Ela foi para o Econo 2017?
# Essa pessoa é de Engenharia Mecânica?
# Ela já trabalhou?
# Ela prefere frio ou calor?
# Essa pessoa torce para o São Paulo?
# Ela dirige?
# Ela faz academia?
# Ela prefere carro ou avião?
# Ela usa óculos?
# Essa pessoa é da sala A?
# O tipo de música favorita dessa pessoa é Eletro?
# Essa pessoa têm 43 anos?
# Essa pessoa têm os olhos de cor azul?
# Ela têm irmãos ou irmãs?
# Ela já viu neve?
# Ela nasceu na cidade de SP?
# Ela prefere chá ou café?
# O cabelo dessa pessoa é loiro?
# Ela prefere salgado ou doce?
# Ela prefere filmes ou séries?
# A cor favorita dessa pessoa é cinza?
# Ela já viajou para fora do Brasil?

# %%
print(len(df))
# Out:
# 19
