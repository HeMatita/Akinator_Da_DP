# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt 
import random
from random import randint

# %%
xl = pd.ExcelFile("EP3_dados.xlsx")
xl.sheet_names
['Planilha1']
df = xl.parse()
df
# Out:
#                   Sala   Engenharia Time que torce  Idade Usa óculos  \
# Ariel                C   Computação      São Paulo     18        Não
# Arthur               A   Computação      Palmeiras     18        Sim
# Christiano           C     Mecânica      São Paulo     19        Sim
# Ester                A     Mecânica      São Paulo     18        Não
# Felipe               B     Mecânica      São Paulo     19        Não
# Fernando             B     Mecânica      Palmeiras     20        Não
# Gabriel              C     Mecânica      Palmeiras     17        Não
# Biro                 B   Computação      São Paulo     21        Não
# João Laet            C     Mecânica      São Paulo     18        Não
# Matita               B  Mecatrônica    Corinthians     18        Não
# Matheus              B     Mecânica         Santos     23        Sim
# Pedro dos Santos     A  Mecatrônica         nenhum     20        Sim
# Pedro Henrique       C  Mecatrônica      Palmeiras     18        Não
# Pedro Isidoro        C     Mecânica       Flamengo     19        Não
# Rodrigo              A  Mecatrônica         nenhum     18        Sim
# Tiago                C  Mecatrônica    Corinthians     18        Sim
# Victor Aprigliano    C  Mecatrônica      São Paulo     19        Não
# Vitão                B     Mecânica         Santos     18        Não
# Daniel               B   Computação    Corinthians     43        Não
# PH                   B   Computação         nenhum     19        Sim
# Delch                B   Computação      Palmeiras     19        Sim
# Rafão                A   Computação         nenhum     18        Sim
# Lucão                B   Computação      São Paulo     18        Sim
# Rafa Almada          B   Computação    Corinthians     19        Sim
#
#                   Nasceu em SP Faz academia Dirige  Celular Namora  \
# Ariel                      Sim          Não    Sim  Android    Sim
# Arthur                     Sim          Não    Não  Android    Sim
# Christiano                 Sim          Sim    Sim   iPhone    Sim
# Ester                      Sim          Não    Não  Android    Não
# Felipe                     Não          Sim    Sim  Android    Sim
# Fernando                   Sim          Sim    Sim   iPhone    Não
# Gabriel                    Sim          Não    Não   iPhone    Não
# Biro                       Não          Sim    Sim  Android    Não
# João Laet                  Sim          Não    Sim  Android    Não
# Matita                     Sim          Não    Não  Android    Sim
# Matheus                    Sim          Sim    Sim  Android    Sim
# Pedro dos Santos           Não          Não    Não  Android    Não
# Pedro Henrique             Não          Sim    Sim   iPhone    Não
# Pedro Isidoro              Não          Sim    Sim  Android    Sim
# Rodrigo                    Não          Sim    Não   iPhone    Não
# Tiago                      Sim          Sim    Sim   iPhone    Sim
# Victor Aprigliano          Sim          Não    Sim   iPhone    Não
# Vitão                      Sim          Sim    Não   iPhone    Não
# Daniel                     Sim          Não    Sim  Android    Sim
# PH                         Não          Não    Não  Android    Não
# Delch                      Sim          Não    Sim  Android    Não
# Rafão                      Não          Não    Não   iPhone    Não
# Lucão                      Sim          Não    Sim  Android    Sim
# Rafa Almada                Sim          Sim    Não  Android    Não
#
#                       ...      Foi pro Econo Já trabalhou Chá ou café  \
# Ariel                 ...                Não          Não        Café
# Arthur                ...                Não          Não         Chá
# Christiano            ...                Não          Não        Café
# Ester                 ...                Não          Sim        Café
# Felipe                ...                Não          Sim        Café
# Fernando              ...                Sim          Sim         Chá
# Gabriel               ...                Não          Não         Chá
# Biro                  ...                Não          Sim         Chá
# João Laet             ...                Sim          Não         Chá
# Matita                ...                Sim          Não        Café
# Matheus               ...                Não          Sim         Chá
# Pedro dos Santos      ...                Sim          Não         Chá
# Pedro Henrique        ...                Não          Não        Café
# Pedro Isidoro         ...                Sim          Não        Café
# Rodrigo               ...                Sim          Não        Café
# Tiago                 ...                Não          Não        Café
# Victor Aprigliano     ...                Sim          Não        Café
# Vitão                 ...                Sim          Não        Café
# Daniel                ...                Não          Sim        Café
# PH                    ...                Não          Não        Café
# Delch                 ...                Sim          Não        Café
# Rafão                 ...                Não          Não        Café
# Lucão                 ...                Não          Não        Café
# Rafa Almada           ...                Não          Não        Café
#
#                   Filme ou série Já viu neve animal de estimação  \
# Ariel                      Filme         Sim                 NaN
# Arthur                     Série         Não                 NaN
# Christiano                 Filme         Sim                 NaN
# Ester                      Filme         Não                 NaN
# Felipe                     Filme         Não                 NaN
# Fernando                   Filme         Sim                 NaN
# Gabriel                    Filme         Sim                 NaN
# Biro                       Filme         Sim                 NaN
# João Laet                  Série         Sim                 NaN
# Matita                     Filme         Não                 NaN
# Matheus                    Filme         Sim                 Não
# Pedro dos Santos           Filme         Sim                 NaN
# Pedro Henrique             Filme         Sim                 NaN
# Pedro Isidoro              Série         Sim                 NaN
# Rodrigo                    Série         Sim                 NaN
# Tiago                      Filme         Sim                 NaN
# Victor Aprigliano          Filme         Sim                 NaN
# Vitão                      Filme         Sim                 NaN
# Daniel                     Filme         Sim                 NaN
# PH                         Série         Sim                 NaN
# Delch                      Filme         Sim                 NaN
# Rafão                      Série         Não                 NaN
# Lucão                      Filme         Sim                 NaN
# Rafa Almada                Série         Sim                 NaN
#
#                   biscoito ou bolacha rodizio japones ou carne  \
# Ariel                             NaN                      NaN
# Arthur                            NaN                      NaN
# Christiano                        NaN                      NaN
# Ester                             NaN                      NaN
# Felipe                            NaN                      NaN
# Fernando                          NaN                      NaN
# Gabriel                           NaN                      NaN
# Biro                              NaN                      NaN
# João Laet                         NaN                      NaN
# Matita                            NaN                      NaN
# Matheus                       Bolacha                      NaN
# Pedro dos Santos                  NaN                      NaN
# Pedro Henrique                    NaN                      NaN
# Pedro Isidoro                     NaN                      NaN
# Rodrigo                           NaN                      NaN
# Tiago                             NaN                      NaN
# Victor Aprigliano                 NaN                      NaN
# Vitão                             NaN                      NaN
# Daniel                            NaN                      NaN
# PH                                NaN                      NaN
# Delch                             NaN                      NaN
# Rafão                             NaN                      NaN
# Lucão                             NaN                      NaN
# Rafa Almada                       NaN                      NaN
#
#                   videogame ou balada descendência
# Ariel                             NaN          NaN
# Arthur                            NaN          NaN
# Christiano                        NaN          NaN
# Ester                             NaN          NaN
# Felipe                            NaN          NaN
# Fernando                          NaN          NaN
# Gabriel                           NaN          NaN
# Biro                              NaN          NaN
# João Laet                         NaN          NaN
# Matita                            NaN          NaN
# Matheus                           NaN   portuguesa
# Pedro dos Santos                  NaN          NaN
# Pedro Henrique                    NaN          NaN
# Pedro Isidoro                     NaN          NaN
# Rodrigo                           NaN          NaN
# Tiago                             NaN          NaN
# Victor Aprigliano                 NaN          NaN
# Vitão                             NaN          NaN
# Daniel                            NaN          NaN
# PH                                NaN          NaN
# Delch                             NaN          NaN
# Rafão                             NaN          NaN
# Lucão                             NaN          NaN
# Rafa Almada                       NaN          NaN
#
# [24 rows x 31 columns]

# %%
dic_salas = {1 : "A", 2 : "B", 3 : "C"}
dic_engenharias = {1 : "Mecânica", 2 : "Mecatrônica", 3 : "de Computação"}
dic_times = {1 : "o Santos", 2 : "o Corinthians", 3 : "o Palmeiras", 4 : "o São Paulo", 5 : "o Flamengo", 6 : "time nenhum"}
dic_idade = {1 : 17, 2 : 18, 3 : 19, 4 : 20, 5 : 21, 6 : 23, 7 : 43}
dic_olhos = {1 : "verde", 2 : "azul", 3 : "castanho"}
dic_cabelo = {1 : "castanho", 2 : "preto", 3 : "loiro"}
dic_musica = {1 : "Pop", 2 : "Rock", 3 : "Rap", 4 : "Gospel", 5 : "Metal", 6 : "Sertanejo", 7 : "Funk", 8 : "Eletro", 9 : "Samba", 10 : "Tecno"}
dic_cor = {1 : "roxo", 2 : "azul", 3 : "verde", 4 : "vermelho", 5 : "cinza", 6 : "preto"}
perguntas = {1 : "Essa pessoa é da sala {} ?".format(dic_salas[randint(1,3)]), 
             2 : "Essa pessoa é de Engenharia {} ?".format(dic_engenharias[randint(1,3)]),
             3 : "Essa pessoa torce para {} ?".format(dic_times[randint(1,6)]),
             4 : "Essa pessoa têm {} anos?".format(dic_idade[randint(1,7)]),
             5 : "Essa pessoa usa óculos ?",
             6 : "Essa pessoa nasceu na cidade de SP ?",
             7 : "Essa pessoa faz academia ?",
             8 : "Essa pessoa dirige ?",
             9 : "Qual tipo de celular que ela prefere ?",
             10 : "Essa pessoa namora ?",
             11 : "Essa pessoa já viajou para fora do Brasil ?",
             12 : "Essa pessoa têm os olhos de cor {} ?".format(dic_olhos[randint(1,3)]),
             13 : "O cabelo dessa pessoa é {} ?".format(dic_cabelo[randint(1,3)]),
             14 : "O tipo de música favorita dessa pessoa é {} ?".format(dic_musica[randint(1,10)]),
             15 : "Onde que essa pessoa gostaria de morar ?",
             16 : "Essa pessoa têm irmãos ou irmãs ?",
             17 : "Essa pessoa prefere salgado ou doce ?",
             18 : "A cor favorita dessa pessoa é {} ?".format(dic_cor[randint(1,6)]),
             19 : "Essa pessoa prefere carro ou avião ?",
             20 : "Essa pessoa prefere frio ou calor ?",
             21 : "Essa pessoa gosta de esportes ?",
             22 : "Essa pessoa foi para o Econo 2017 ?",
             23 : "Essa pessoa já trabalhou ?",
             24 : "Essa pessoa prefere chá ou café ?",
             25 : "Essa pessoa prefere filmes ou séries ?",
             26 : "Essa pessoa já viu neve ?"}

# %%
perguntas[4].split()[-2]
# Out:
# '20'

# %%
respostas = {1 : "1 - Sim\n2 - Não\n3 - Não sei",
            2 : "1 - Sim\n2 - Não\n3 - Não sei",
            3 : "1 - Sim\n2 - Não\n3 - Não sei",
            4 : "1 - Sim\n2 - Não\n3 - Não sei",
            5 : "1 - Sim\n2 - Não\n3 - Não sei",
            6 : "1 - Sim\n2 - Não\n3 - Não sei",
            7 : "1 - Sim\n2 - Não\n3 - Não sei",
            8 : "1 - Sim\n2 - Não\n3 - Não sei",
            9 : "1 - Android\n2 - iPhone\n3 - Não sei",
            10 : "1 - Sim\n2 - Não\n3 - Não sei",
            11 : "1 - Sim\n2 - Não\n3 - Não sei",
            12 : "1 - Sim\n2 - Não\n3 - Não sei",
            13 : "1 - Sim\n2 - Não\n3 - Não sei",
            14 : "1 - Sim\n2 - Não\n3 - Não sei",
            15 : "1 - Casa\n2 - Apartamento\n3 - Não sei",
            16 : "1 - Sim\n2 - Não\n3 - Não sei",
            17 : "1 - Salgado\n2 - Doce\n3 - Não sei",
            18 : "1 - Sim\n2 - Não\n3 - Não sei",
            19 : "1 - Carro\n2 - Avião\n3 - Não sei",
            20 : "1 - Frio\n2 - Calor\n3 - Não sei",
            21 : "1 - Sim\n2 - Não\n3 - Não sei",
            22 : "1 - Sim\n2 - Não\n3 - Não sei",
            23 : "1 - Sim\n2 - Não\n3 - Não sei",
            24 : "1 - Chá\n2 - Café\n3 - Não sei",
            25 : "1 - Filmes\n2 - Séries\n3 - Não sei",
            26 : "1 - Sim\n2 - Não\n3 - Não sei"}

# %%
p = random.sample(range(1,27), 26)
print(p)
# Out:
# [26, 4, 14, 18, 22, 9, 7, 16, 5, 21, 23, 6, 2, 20, 13, 12, 1, 25, 10, 24, 11, 19, 8, 17, 3, 15]

# %%
for i in range(len(p)):
    if i > 0:
        print(p[i-1])
    #df[(df.iloc[:, p[i]+1] == perguntas[p[i]].split()[-2])]
# Out:
# 26
# 4
# 14
# 18
# 22
# 9
# 7
# 16
# 5
# 21
# 23
# 6
# 2
# 20
# 13
# 12
# 1
# 25
# 10
# 24
# 11
# 19
# 8
# 17
# 3

# %%
for i in range(len(p)):
    print(perguntas[p[i]])
    x = int(input((respostas[p[i]])))
    if p[i] == 1 or p[i] == 2 or p[i] == 3 or p[i] == 12 or p[i] == 13 or p[i] == 14 or p[i] == 18:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == perguntas[p[i]].split()[-2])]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] != perguntas[p[i]].split()[-2])]
            print(len(df))
    if p[i] == 4:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == int(perguntas[p[i]].split()[-2]))]
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] != int(perguntas[p[i]].split()[-2]))]
    if p[i] == 5 or p[i] == 6 or p[i] == 7 or p[i] == 8 or p[i] == 10 or p[i] == 11 or p[i] == 16 or p[i] == 21 or p[i] == 22 or p[i] == 23 or p[i] == 26:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == "Sim")]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] == "Não")]
            print(len(df))
    if p[i] == 9:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == "Android")]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] == "iPhone")]
            print(len(df))
    if p[i] == 15:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == "Casa")]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] == "Apartamento")]
            print(len(df))
    if p[i] == 17:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == "Salgado")]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] == "Doce")]
            print(len(df))
    if p[i] == 19:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == "Carro")]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] == "Avião")]
            print(len(df))
    if p[i] == 20:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == "Frio")]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] == "Calor")]
            print(len(df))
    if p[i] == 24:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == "Chá")]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] == "Café")]
            print(len(df))
    if p[i] == 25:
        if x == 1:
            df = df[(df.iloc[:, p[i]-1] == "Filme")]
            print(len(df))
        if x == 2:
            df = df[(df.iloc[:, p[i]-1] == "Série")]
            print(len(df))
    if len(df) == 1:
        break
    if x == 3:
        df = df
    if x == 4:
        break
print("A pessoa que você está pensando deve ser o {}!!".format(list(df.index)[0]))
# Out:
# Essa pessoa já viu neve ?
# 1 - Sim
# 2 - Não
# 3 - Não sei2
# 5
# Essa pessoa têm 20 anos?
# 1 - Sim
# 2 - Não
# 3 - Não sei2
# O tipo de música favorita dessa pessoa é Pop ?
# 1 - Sim
# 2 - Não
# 3 - Não sei2
# 4
# A cor favorita dessa pessoa é roxo ?
# 1 - Sim
# 2 - Não
# 3 - Não sei2
# 2
# Essa pessoa foi para o Econo 2017 ?
# 1 - Sim
# 2 - Não
# 3 - Não sei1
# 0
# Qual tipo de celular que ela prefere ?
# 1 - Android
# 2 - iPhone
# 3 - Não sei1
# 0
# Essa pessoa faz academia ?
# 1 - Sim
# 2 - Não
# 3 - Não sei2
# 0
# Essa pessoa têm irmãos ou irmãs ?
# 1 - Sim
# 2 - Não
# 3 - Não sei1
# 0
# Essa pessoa usa óculos ?
# 1 - Sim
# 2 - Não
# 3 - Não sei2
# 0
# Essa pessoa gosta de esportes ?
# 1 - Sim
# 2 - Não
# 3 - Não sei1
# 0
# Essa pessoa já trabalhou ?
# 1 - Sim
# 2 - Não
# 3 - Não sei2
# 0
# Essa pessoa nasceu na cidade de SP ?
# 1 - Sim
# 2 - Não
# 3 - Não sei1
# 0
# Essa pessoa é de Engenharia Mecatrônica ?
# 1 - Sim
# 2 - Não
# 3 - Não sei1
# 0
# Essa pessoa prefere frio ou calor ?
# 1 - Frio
# 2 - Calor
# 3 - Não sei1
# 0
# O cabelo dessa pessoa é castanho ?
# 1 - Sim
# 2 - Não
# 3 - Não sei2
# 0
# Essa pessoa têm os olhos de cor castanho ?
# 1 - Sim
# 2 - Não
# 3 - Não sei1
# 0
# Essa pessoa é da sala B ?
# 1 - Sim
# 2 - Não
# 3 - Não sei1
# 0
# Essa pessoa prefere filmes ou séries ?
# 1 - Filmes
# 2 - Séries
# 3 - Não sei1
# 0
# Essa pessoa namora ?
# 1 - Sim
# 2 - Não
# 3 - Não sei1
# 0
# Essa pessoa prefere chá ou café ?
# 1 - Chá
# 2 - Café
# 3 - Não sei2
# 0
# Essa pessoa já viajou para fora do Brasil ?

# %%
df[(df.iloc[:, p[12]-1] == perguntas[p[12]].split()[-2])]

# %%
print("Olá, e bem vindo(a) ao Gênio de DeSoft!!\nPeço para que pense em alguma pessoa que fez a matéria de DeSoft nesse semestre.\nJá pensou?\nÓtimo, agora vou adivinhar quem é essa pessoa que você está pensando!!\nBom jogo!!")
# Out:
# Olá, e bem vindo(a) ao Gênio de DeSoft!!
# Peço para que pense em alguma pessoa que fez a matéria de DeSoft nesse semestre.
# Já pensou?
# Ótimo, agora vou adivinhar quem é essa pessoa que você está pensando!!
# Bom jogo!!

# %%
print("A pessoa que você está pensando deve ser o {}!!".format(list(df.index)[0]))
# Out:
# A pessoa que você está pensando deve ser o Matita!!

# %%
l = [10, 20]
print(l[randint(0,1)])
